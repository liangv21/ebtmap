# %%
import pandas as pd

# %%
flight_df = pd.read_csv('finaloutput.csv')

# %%
flight_df
# Out:
#      Unnamed: 0  icao iata                                               name  \
# 0             0  KDCA  DCA  Ronald Reagan Washington National, District of...
# 1             1  KJFK  JFK                           John F Kennedy, New York
# 2             2  KMCO  MCO                                   Orlando, Orlando
# 3             3  KLGA  LGA                               La Guardia, New York
# 4             4  KORD  ORD                            Chicago O'Hare, Chicago
# ..          ...   ...  ...                                                ...
# 364         364  TTCP  TAB                    Tobago-Crown Point, Scarborough
# 365         365  KSTL  STL                      Lambert St Louis, Saint Louis
# 366         366  KTEB  TEB                               Teterboro, Teterboro
# 367         367  KICT  ICT                     Wichita Mid Continent, Wichita
# 368         368  LEZG  ZAZ                        Zaragoza Air Base, Zaragoza
#
# ...

# %%
del flight_df['Unnamed: 0']

# %%
flight_df
# Out:
#      icao iata                                               name  \
# 0    KDCA  DCA  Ronald Reagan Washington National, District of...
# 1    KJFK  JFK                           John F Kennedy, New York
# 2    KMCO  MCO                                   Orlando, Orlando
# 3    KLGA  LGA                               La Guardia, New York
# 4    KORD  ORD                            Chicago O'Hare, Chicago
# ..    ...  ...                                                ...
# 364  TTCP  TAB                    Tobago-Crown Point, Scarborough
# 365  KSTL  STL                      Lambert St Louis, Saint Louis
# 366  KTEB  TEB                               Teterboro, Teterboro
# 367  KICT  ICT                     Wichita Mid Continent, Wichita
# 368  LEZG  ZAZ                        Zaragoza Air Base, Zaragoza
#
#                              shortName      municipalityName countryCode  \
# 0    Ronald Reagan Washington National  District of Columbia          US
# ...

# %%
flight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   icao                 369 non-null    object
#  1   iata                 369 non-null    object
#  2   name                 369 non-null    object
#  3   shortName            282 non-null    object
#  4   municipalityName     369 non-null    object
#  5   countryCode          369 non-null    object
#  6   lat                  369 non-null    float64
#  7   lon                  369 non-null    float64
#  8   from                 369 non-null    object
#  9   averageDailyFlights  369 non-null    float64
#  10  dist                 369 non-null    float64
#  11  co2KGPerPerson       369 non-null    float64
#  12  percentageco2(%)     369 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 37.6+ KB

# %%
del flight_df['shortName']

# %%
del flight_df['icao']

# %%
flight_df.head()
# Out:
#   iata                                               name  \
# 0  DCA  Ronald Reagan Washington National, District of...
# 1  JFK                           John F Kennedy, New York
# 2  MCO                                   Orlando, Orlando
# 3  LGA                               La Guardia, New York
# 4  ORD                            Chicago O'Hare, Chicago
#
#        municipalityName countryCode      lat      lon from  \
# 0  District of Columbia          US  38.8521 -77.0377  BOS
# 1              New York          US  40.6398 -73.7789  BOS
# 2               Orlando          US  28.4294 -81.3090  BOS
# 3              New York          US  40.7772 -73.8726  BOS
# 4               Chicago          US  41.9786 -87.9048  BOS
#
#    averageDailyFlights     dist  co2KGPerPerson  percentageco2(%)
# 0                27.81   641.97           73.83          2.034591
# 1                21.14   300.30           34.53          0.951570
# ...

# %%
flight_df.to_csv('finaloutput.csv')
